# %% [markdown]
# #### Q1 ![image.png](attachment:image.png)

# %%
keys = ['Ten', 'Twenty', 'Thrity']
values = [10, 20, 30]
d = {}
for i,j in zip(keys,values):
    d[i] = j
d
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thrity': 30}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dict1 = {'Ten': 10, 'Twenty': 20, 'Thrity': 30}
dict2 = {'Thrity': 30, 'Fourty': 40, 'Fifty': 50}
d = dict1.copy()
d.update(dict2)

# %%
d
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thrity': 30, 'Fourty': 40, 'Fifty': 50}

# %% [markdown]
# #### Exercise 3: Print the value of key ‘history’ from the below dict
#
# sampleDict = {
#     "class": {
#         "student": {
#             "name": "Mike",
#             "marks": {
#                 "physics": 70,
#                 "history": 80
#             }
#         }
#     }
# }

# %%
sampleDict = {
    "class": {
        "student": {
            "name": "Mike",
            "marks": {
                "physics": 70,
                "history": 80
            }
        }
    }
}

# %%
sampleDict['class']['student']['marks']['history']
# Out:
# 80

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
emplyoee = ['Kelly', 'Emma']
defaults = {'designation': 'Developer', 'salary': 8000}
d = {}
for i in emplyoee:
    d[i]= defaults
d
# Out:
# {'Kelly': {'designation': 'Developer', 'salary': 8000},
#  'Emma': {'designation': 'Developer', 'salary': 8000}}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#we cannot iterate a dictory directory, by using d.iteams you can iterate keys,values at a time
sample_dict = {"name": "kelly", "age": 25, "Salary": 8000, "city": "new york"}
d = {}
for key, value in sample_dict.items():
    if key == "name" or key == "Salary":
        d[key] = value
d
# Out:
# {'name': 'kelly', 'Salary': 8000}

# %%
keys = ['name', 'Salary']
d = {}
for i in keys:
    d[i] = sample_dict[i]
d
# Out:
# {'name': 'kelly', 'Salary': 8000}

# %%
#dict comprehensive
{i: sample_dict[i] for i in keys}
# Out:
# {'name': 'kelly', 'Salary': 8000}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s_dict = {"name": "kelly", "age": 25, "salary": 8000, "city": "new york"}
d = {}
for key,value in s_dict.items():
    if key == "age" or key == "city":
        d[key] = value
d
# Out:
# {'age': 25, 'city': 'new york'}

# %%
keys = ['name', 'salary']
for i in keys:
    s_dict.pop(i)
s_dict
# Out:
# {'age': 25, 'city': 'new york'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = {'a': 100, 'b':200, 'c': 300}
for value in s.values():
    if value == 200:
        print(f"{value} present in a dict")
# Out:
# 200 present in a dict

# %%
sample_dict = {'a': 100, 'b': 200, 'c': 300}
if 200 in sample_dict.values():
    print('200 present in a dict')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s_dict = {"name": "kelly", "age": 25, "salary": 8000, "city": "new york"}
s_dict['location'] = s_dict.pop("city")

# %%
s_dict
# Out:
# {'name': 'kelly', 'age': 25, 'salary': 8000, 'location': 'new york'}

# %%
sample_dict = {
    "name": "Kelly",
    "age": 25,
    "salary": 8000,
    "city": "New york"
}

sample_dict.pop('city')
# print(sample_dict)
# Out:
# 'New york'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = {"Physics": 82, "Math": 65, "history": 75}
d = {}
for key,value in s.items():
    d[value]=key
print(d[min(d.keys())])
# Out:
# Math

# %%
s = {"Physics": 82, "Math": 65, "history": 75}
s_reverse = {value: key for key,value in s.items()}
print(s_reverse)
s_reverse[min(s_reverse.keys())]
# Out:
# {82: 'Physics', 65: 'Math', 75: 'history'}
# 'Math'

# %%
sample_dict = {
    'Physics': 82,
    'Math': 65,
    'history': 75
}
print(min(sample_dict, key=sample_dict.get))
# Out:
# Math

# %%
min(sample_dict)
# Out:
# 'Math'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sample_dict = {
    'emp1': {'name': 'Jhon', 'salary': 7500},
    'emp2': {'name': 'Emma', 'salary': 8000},
    'emp3': {'name': 'Brad', 'salary': 500}
}
sample_dict['emp3']['salary'] = 8500

# %%
sample_dict
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500},
#  'emp2': {'name': 'Emma', 'salary': 8000},
#  'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# #                                       THE END
