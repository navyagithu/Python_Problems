# %% [markdown]
# ![image.png](attachment:image.png)

# %%
restaurant_customers = {
  'John Steven': (10, 'still waiting'),
  'Jane Black': (5, 'still waiting'),
  'Mark Dawson': (15, 'got the food :)'),
  'Janet Roberts': (30, 'left without eating :('),
  'John Parker': (22, 'still waiting'),
  'Anne Edwards': (18, 'got the food :)'),
  'Mary Rogers': (7, 'got the food :)'),
  'Emma Reed': (35, 'got the food :)'),
  'Sophia Steven': (25, 'still waiting'),
  'Amelia Cook': (32, 'still waiting'),
  'John Scott': (15, 'still waiting'),
  'George Famous': (20, 'still waiting'),
  'Jack Baker': (38, 'got the food :)')
}
d = restaurant_customers.copy()
count = 0
for key,value in restaurant_customers.items():
    if value[0]>=20 and value[1] == "still waiting":
        d[key] = value[0], "left without eating :("
for i in d.values():
    if i[1] == "left without eating :(":
      count = count+1
print(f"{count} customer has left without eating")
# Out:
# 5 customer has left without eating

# %%
restaurant_customers = {
  'John Steven': (10, 'still waiting'),
  'Jane Black': (5, 'still waiting'),
  'Mark Dawson': (15, 'got the food :)'),
  'Janet Roberts': (30, 'left without eating :('),
  'John Parker': (22, 'still waiting'),
  'Anne Edwards': (18, 'got the food :)'),
  'Mary Rogers': (7, 'got the food :)'),
  'Emma Reed': (35, 'got the food :)'),
  'Sophia Steven': (25, 'still waiting'),
  'Amelia Cook': (32, 'still waiting'),
  'John Scott': (15, 'still waiting'),
  'George Famous': (20, 'still waiting'),
  'Jack Baker': (38, 'got the food :)')
}
 
counter = 0
for customer in restaurant_customers:
  time, status = restaurant_customers[customer]
  if time >= 20 and status != 'got the food :)':
    status = 'left without eating :('
  if status == 'left without eating :(':
    counter += 1
    restaurant_customers[customer] = (time, status)
    print(counter, 'customers left.')
# Out:
# 1 customers left.
# 2 customers left.
# 3 customers left.
# 4 customers left.
# 5 customers left.

# %% [markdown]
# #### Q2:
# Simplify the template code so that it uses the get() function.
#
# employees = [
# ('Maria', 'Polish'), ('Jean', 'French'),
# ('Juan', 'Spanish'), ('Dima', 'Ukrainian'),
# ('Agata', 'Polish'), ('Rafal', 'Polish'),
# ('Diego', 'Spanish'), ('Stan', 'Ukrainian')
# ]
#
# dict_results = {}
# for employee in employees:
#   _, nationality = employee
# if nationality not in dict_results:
#   dict_results[nationality] = 0
#   dict_results[nationality] += 1

# %%
employees = [
('Maria', 'Polish'), ('Jean', 'French'),
('Juan', 'Spanish'), ('Dima', 'Ukrainian'),
('Agata', 'Polish'), ('Rafal', 'Polish'),
('Diego', 'Spanish'), ('Stan', 'Ukrainian')
]
 
dict_results = {}
for employee in employees:
  _, nationality = employee
  if nationality not in dict_results:
    dict_results[nationality] = 1
  else:
    dict_results[nationality] += 1

# %%
dict_results
# Out:
# {'Polish': 3, 'French': 1, 'Spanish': 2, 'Ukrainian': 2}

# %%
employees = [
('Maria', 'Polish'), ('Jean', 'French'),
('Juan', 'Spanish'), ('Dima', 'Ukrainian'),
('Agata', 'Polish'), ('Rafal', 'Polish'),
('Diego', 'Spanish'), ('Stan', 'Ukrainian')
]
 
dict_results = {}
for employee in employees:
  _, nationality = employee
  dict_results[nationality] = dict_results.get(nationality,0) + 1
 
print(dict_results)



# First, we create an empty dictionary called dict_results, and then we iterate through the employees dictionary.

# Each employee is represented by a tuple with 2 elements: the first element is the name, and the second one is the nationality. We use the get() function to append the number of nationals for a given nationality.

# After printing, we get the following output:

# {'Polish': 3, 'French': 1, 'Spanish': 2, 'Ukrainian': 2}
# Out:
# {'Polish': 3, 'French': 1, 'Spanish': 2, 'Ukrainian': 2}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
airport_runways = [
('Warsaw', 2), ('Vienna', 2),
('Frankfurt', 4), ('London Heathrow', 2),
('Fukuoka', 1), ('Madrid', 4)
]
runways = {}
l1,l2,l3 = [],[],[]
for i in airport_runways:
    if i[1] == 2:
        runways[i[1]] = l1.append(i[0])
        runways[i[1]]=l1
# print(runways)
    elif i[1] == 1:
        runways[i[1]] = l2.append(i[0])
        runways[i[1]] = l2
# print(runways)
    elif i[1] == 4:
        runways[i[1]] = l3.append(i[0])
        runways[i[1]] = l3
print(runways)
# Out:
# {2: ['Warsaw', 'Vienna', 'London Heathrow'], 4: ['Frankfurt', 'Madrid'], 1: ['Fukuoka']}

# %%
airport_runways = [
    ('Warsaw', 2), ('Vienna', 2),
    ('Frankfurt', 4), ('London Heathrow', 2),
    ('Fukuoka', 1), ('Madrid', 4)
]

runways = {}

for airport, num_runways in airport_runways:
    if num_runways not in runways:
        runways[num_runways] = []  # Initialize the list if key doesn't exist
    runways[num_runways].append(airport)  # Append the airport to the list

print(runways)
# Out:
# {2: ['Warsaw', 'Vienna', 'London Heathrow'], 4: ['Frankfurt', 'Madrid'], 1: ['Fukuoka']}

# %% [markdown]
# #### 4.  Linking Python Dictionaries
# Directions
# You are given a dictionary with salaries for 2017. Create a copy of this dictionary and name it salaries_2018. In 2018, everyone got a 10% raise. Update the 2018 dictionary to reflect the raise; each value in salaries_2018 should be an integer.
# Finally, print both dictionaries and observe that the values in the dictionary salaries_2017 were not modified. This confirms that salaries_2018 is a separate dictionary.
#
# salaries_2017 = {'Anna': 4000, 'Mark': 5000, 'Jane': 5500, 'John': 3000}

# %%
salaries_2017 = {'Anna': 4000, 'Mark': 5000, 'Jane': 5500, 'John': 3000}
salaries_2018 = salaries_2017.copy()
for key, value in salaries_2017.items():
    salaries_2018[key] = int(value+(value*(10/100)))
print("salaries_2017 : ", salaries_2017)
print("salaries_2018 : ", salaries_2018)
# Out:
# salaries_2017 :  {'Anna': 4000, 'Mark': 5000, 'Jane': 5500, 'John': 3000}
# salaries_2018 :  {'Anna': 4400, 'Mark': 5500, 'Jane': 6050, 'John': 3300}

# %%
m = 50
m*1.50
# Out:
# 75.0

# %% [markdown]
# #### Q5.  The Python update() Function
# Directions
# You are given a dictionary with salaries for 2019. Use the salaries_update dictionary to update salaries for 2019. Print the modified salaries_2019 dictionary.
#
# Note that a new employee, Mary, has been added to salaries_2019.
#
# Starter Code
#
# salaries_2019 = {'Anna': 5000, 'Mark': 5000, 'Jane': 6500, 'John': 3500}
#
# salaries_update = {'Anna': 5500, 'Mary': 4000}

# %%
salaries_2019 = {'Anna': 5000, 'Mark': 5000, 'Jane': 6500, 'John': 3500}

salaries_update = {'Anna': 5500, 'Mary': 4000}

salaries_2019.update(salaries_update)

salaries_2019
# Out:
# {'Anna': 5500, 'Mark': 5000, 'Jane': 6500, 'John': 3500, 'Mary': 4000}

# %% [markdown]
# #### Q6: Rewrite the template code so that it uses the get() function.
# airport_runways = [
# ('Warsaw', 2),
# ('Vienna', 2),
# ('Frankfurt', 4),
# ('London Heathrow', 2),
# ('Fukuoka', 1),
# ('Madrid', 4)
# ]
#
# runways = {}
# for airport in airport_runways:
#   airport_name, runway = airport
# if runway not in runways:
#   runways[runway] = []
#   runways[runway].append(airport_name)

# %%
airport_runways = [
('Warsaw', 2),
('Vienna', 2),
('Frankfurt', 4),
('London Heathrow', 2),
('Fukuoka', 1),
('Madrid', 4)
]
 
runways = {}
for airport in airport_runways:
  airport_name, runway = airport
  runways[runway] = runways.get(runway, []) + [airport_name]
# if runway not in runways:
#   runways[runway] = []
#   runways[runway].append(airport_name)

runways
# Out:
# {2: ['Warsaw', 'Vienna', 'London Heathrow'],
#  4: ['Frankfurt', 'Madrid'],
#  1: ['Fukuoka']}

# %%
12500*1.05
# Out:
# 13125.0

# %% [markdown]
# #### Q7:  Delete the dictionary item from 2001.
#
# Ask the user to provide an integer. Use the prompt “Enter a year between 2000 and 2018 to check if there was a major Windows release”.
#
# If there is an item for the given year in os_releases, print:
# A major version found: {os_release}.
# Otherwise, print:
# No major version found.
#
#
# os_releases = {
# 2015: 'Windows 10',
# 2013: 'Windows 8.1',
# 2012: 'Windows 8',
# 2009: 'Windows 7',
# 2007: 'Windows Vista',
# 2001: 'Windows XP'
# }
#
# user_key = int(input('Enter a year between 2000 and 2018 to check if there was a major Windows release. '))

# %%
os_releases = {
2015: 'Windows 10',
2013: 'Windows 8.1',
2012: 'Windows 8',
2009: 'Windows 7',
2007: 'Windows Vista',
2001: 'Windows XP'
}
 
user_key = int(input('Enter a year between 2000 and 2018 to check if there was a major Windows release. '))
if user_key in os_releases.keys():
    print("A major version found: ", os_releases[user_key] )
else:
    print("No major version found")
# Out:
# A major version found:  Windows Vista

# %% [markdown]
# #### Q8: Iterating Over Python Dictionaries Using items()
# Directions
# Windows 1.0 was the first major operating system released by Microsoft (in 1985). For each system version in the dictionary, print the following sentence:
#
# {version_name} was released in {year} - {x} years after Windows 1.0.
#
# os_releases = {
# 2015: 'Windows 10',
# 2013: 'Windows 8.1',
# 2012: 'Windows 8',
# 2009: 'Windows 7',
# 2007: 'Windows Vista',
# 2001: 'Windows XP'}

# %%
#{version_name} was released in {year} - {x} years after Windows 1.0.
x = 1985
os_releases = {
2015: 'Windows 10',
2013: 'Windows 8.1',
2012: 'Windows 8',
2009: 'Windows 7',
2007: 'Windows Vista',
2001: 'Windows XP'}

for year, os in os_releases.items():
    print(f"{os} was released in {year} - {year-x} years after Windows 1.0.")
# Out:
# Windows 10 was released in 2015 - 30 years after Windows 1.0.
# Windows 8.1 was released in 2013 - 28 years after Windows 1.0.
# Windows 8 was released in 2012 - 27 years after Windows 1.0.
# Windows 7 was released in 2009 - 24 years after Windows 1.0.
# Windows Vista was released in 2007 - 22 years after Windows 1.0.
# Windows XP was released in 2001 - 16 years after Windows 1.0.

# %% [markdown]
# #### Q9 : Python Dictionaries as Function Arguments
# Directions
# Write a function named max_value() that takes a dictionary and returns its greatest value. Assume that all values in the dictionary are natural numbers.
# Hint
# Create a temporary variable in the function with an initial value of 0.

# %%
def max_value(d):
    temp_var = 0
    for value in d.values():
        value>=max(d.values())
        temp_var = value
    return temp_var

# %%
max_value({'navya': 22, 'kranthi': 20, 'simla': 60})
# Out:
# 60

# %%
d = {'navya': 22, 'kranthi': 20, 'simla': 30}
max(d.values())
# for i in d.values():
# Out:
# 30

# %% [markdown]
# #### Q10: Returning Python Dictionaries from Functions
# Modify the function add_ten so that it returns a new dictionary instead of modifying the dictionary passed in as an argument.
#
# def add_ten(dictionary):
#   for key in dictionary.keys():
#     if dictionary[key] % 2 == 0:
#       dictionary[key] += 10

# %%
def add_ten(dictionary):
  d = dictionary.copy()
  for key in d.keys():
    if d[key] % 2 == 0:
      d[key] += 10
  return d

# %%
add_ten({'navya': 22, 'kranthi': 3, 'simla': 30})
# Out:
# {'navya': 32, 'kranthi': 3, 'simla': 40}

# %% [markdown]
# # THE END
